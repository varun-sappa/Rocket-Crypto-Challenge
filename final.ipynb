# %%
#libraries

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.dates as mandates
from sklearn import linear_model
from keras.models import Sequential
from keras.layers import Dense

import keras.backend as K
from keras.callbacks import EarlyStopping
#from Keras.models import load_model
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model
import tensorflow as tf
import keras

# %%
dfv=pd.read_csv(r'C:\Users\varun\Downloads\QmWNurQsLnvvJfTkfNd4rA3Qap11WmX8Upfr9paBx3Mxs9\dataset\validation_dataset.csv')

# %%
#Get the Dataset
df=pd.read_csv(r'C:\Users\varun\Downloads\QmWNurQsLnvvJfTkfNd4rA3Qap11WmX8Upfr9paBx3Mxs9\dataset\train_dataset.csv')
df.head()
# Out:
#          date symbol  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  2018-04-29    BTC   0.000000   0.000000   0.965517   0.000000   0.000000
# 1  2018-04-29    DLT   0.310345   0.310345   0.137931   0.275862   0.206897
# 2  2018-04-29    ENJ   0.241379   0.068966   0.310345   0.344828   0.103448
# 3  2018-04-29    OMG   0.758621   0.965517   0.896552   0.965517   0.965517
# 4  2018-04-29    UFR   0.620690   0.413793   0.275862   0.413793   0.517241
#
#    feature_6  feature_7  feature_8  ...  feature_2003  feature_2004  \
# 0   0.000000   0.000000   0.000000  ...      0.689655      0.655172
# 1   0.517241   0.344828   0.689655  ...      0.206897      0.206897
# 2   0.103448   0.379310   0.206897  ...      0.379310      0.344828
# 3   0.965517   0.068966   0.275862  ...      0.896552      0.931034
# 4   0.362069   0.758621   0.586207  ...      0.482759      0.275862
#
#    feature_2005  feature_2006  feature_2007  feature_2008  feature_2009  \
# ...

# %%
symbols=dfv["symbol"].unique()
symbols
# Out:
# array(['BTC', 'XRP', 'SRN', 'SALT', 'REQ', 'QSP', 'PRE', 'USDT', 'GET',
#        'FUN', 'ETH', 'PAY', 'PLAY', 'PRO', 'TRAC', 'KNC', 'KEY', 'AGIX',
#        'BAT', 'CHAT', 'HT', 'DRGN', 'VGX', 'OMG', 'DCN', 'ENJ', 'PLR',
#        'VEE', 'ANT', 'AST', 'BRD', 'FUEL', 'ZRX', 'VIB', 'WABI', 'OCN',
#        'CRPT', 'VIBE', 'PPT', 'MTL', 'DNT', 'GNO', 'POWR', 'DENT', 'WPR',
#        'TKN', 'STAR', 'MTN', 'RCN', 'POLY', 'GLM', 'REM', 'NCASH', 'ABT',
#        'AXP', 'GVT', 'MANA', 'DGD', 'RDN', 'UTK', 'MKR', 'ELF', 'POE',
#        'TNB', 'TEL', 'CND', 'ENG', 'CHP', 'SNT', 'TEN', 'STORM', 'ELEC',
#        'QASH', 'CAS', 'BFT', 'SAN', 'BNT', 'DMT', 'ZAP', 'FDZ', 'NCT',
#        'RFR', 'BLZ', 'MTH', 'GEM', 'LINK', 'DATA', 'BAX', 'RUFF', 'HOT',
#        'CEL', 'RLC', 'IHT', 'NEXO', 'GEN', 'CNN', 'DGX', 'LBA', 'REN',
#        'SPD', 'FACE', 'QKC', 'ADB', 'MYB', 'CBC', 'OAX', 'XBP', 'COV',
#        'STORJ', 'LET', 'UUU', 'MFT', 'REP', 'AOA', 'HSC', 'BMX', 'CXO',
# ...

# %%
df = df[df.symbol.isin(symbols[0:709]) == True]

# %%
symbols[0:709]
# Out:
# array(['BTC', 'XRP', 'SRN', 'SALT', 'REQ', 'QSP', 'PRE', 'USDT', 'GET',
#        'FUN', 'ETH', 'PAY', 'PLAY', 'PRO', 'TRAC', 'KNC', 'KEY', 'AGIX',
#        'BAT', 'CHAT', 'HT', 'DRGN', 'VGX', 'OMG', 'DCN', 'ENJ', 'PLR',
#        'VEE', 'ANT', 'AST', 'BRD', 'FUEL', 'ZRX', 'VIB', 'WABI', 'OCN',
#        'CRPT', 'VIBE', 'PPT', 'MTL', 'DNT', 'GNO', 'POWR', 'DENT', 'WPR',
#        'TKN', 'STAR', 'MTN', 'RCN', 'POLY', 'GLM', 'REM', 'NCASH', 'ABT',
#        'AXP', 'GVT', 'MANA', 'DGD', 'RDN', 'UTK', 'MKR', 'ELF', 'POE',
#        'TNB', 'TEL', 'CND', 'ENG', 'CHP', 'SNT', 'TEN', 'STORM', 'ELEC',
#        'QASH', 'CAS', 'BFT', 'SAN', 'BNT', 'DMT', 'ZAP', 'FDZ', 'NCT',
#        'RFR', 'BLZ', 'MTH', 'GEM', 'LINK', 'DATA', 'BAX', 'RUFF', 'HOT',
#        'CEL', 'RLC', 'IHT', 'NEXO', 'GEN', 'CNN', 'DGX', 'LBA', 'REN',
#        'SPD', 'FACE', 'QKC', 'ADB', 'MYB', 'CBC', 'OAX', 'XBP', 'COV',
#        'STORJ', 'LET', 'UUU', 'MFT', 'REP', 'AOA', 'HSC', 'BMX', 'CXO',
# ...

# %%
df
# Out:
#              date symbol  feature_1  feature_2  feature_3  feature_4  \
# 0      2018-04-29    BTC   0.000000   0.000000   0.965517   0.000000
# 2      2018-04-29    ENJ   0.241379   0.068966   0.310345   0.344828
# 3      2018-04-29    OMG   0.758621   0.965517   0.896552   0.965517
# 5      2018-04-29    VGX   0.793103   0.758621   0.517241   0.500000
# 6      2018-04-29   DRGN   0.689655   0.793103   0.000000   0.586207
# ...           ...    ...        ...        ...        ...        ...
# 87474  2022-08-21   SMTY   0.638649   0.739943   0.732759   0.713362
# 87475  2022-08-21    SLP   0.464799   0.865661   0.741379   0.857759
# 87476  2022-08-21   SKEY   0.619971   0.193966   0.161638   0.234195
# 87477  2022-08-21   UNCX   0.093391   0.280891   0.275862   0.099856
# 87478  2022-08-21    MPL   0.154454   0.606322   0.077586   0.045977
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_2003  \
# ...

# %%
for (uniquerow), group in df.groupby(df.symbol):
    globals()[uniquerow] = group

# %%
df[df['symbol']=='WIKEN']
# Out:
#              date symbol  feature_1  feature_2  feature_3  feature_4  \
# 87213  2022-08-21  WIKEN   0.464799   0.471983   0.533764   0.561782
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_2003  \
# 87213   0.498563   0.465517   0.519397   0.496408  ...      0.551724
#
#        feature_2004  feature_2005  feature_2006  feature_2007  feature_2008  \
# 87213      0.554598      0.438218      0.643678      0.600575      0.512931
#
#        feature_2009  feature_DC1   target  target_DC1
# 87213       0.71408     0.663793  0.91954    0.041124
#
# [1 rows x 2014 columns]

# %%
XRP
# Out:
#              date symbol  feature_1  feature_2  feature_3  feature_4  \
# 18     2018-04-29    XRP   0.034483   0.034483   0.931034   0.655172
# 83     2018-05-06    XRP   0.000000   0.018519   0.000000   0.888889
# 134    2018-05-13    XRP   0.058824   0.000000   0.000000   0.000000
# 178    2018-05-20    XRP   0.022727   0.011364   0.000000   0.011364
# 307    2018-05-27    XRP   0.829787   0.021277   0.010638   0.000000
# ...           ...    ...        ...        ...        ...        ...
# 84144  2022-07-24    XRP   0.002865   0.998567   0.000000   0.997135
# 84672  2022-07-31    XRP   0.004243   0.001414   0.997171   0.000000
# 85384  2022-08-07    XRP   0.997167   0.997167   0.001416   0.998584
# 86318  2022-08-14    XRP   0.004310   0.004310   0.002874   0.002874
# 87007  2022-08-21    XRP   0.000000   0.001437   0.001437   0.001437
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_2003  \
# ...

# %%
# del df

# %%
# import warnings
# warnings.filterwarnings("ignore")

# %%
cor=[[] for i in range(709)]

# %%
for j in range (0,709):
    for i in range (0,2009):
        cor[j].append(globals()[symbols[j]]['feature_'+ str(i+1)].corr(globals()[symbols[j]]['target']))
# Out:
# C:\Users\varun\anaconda3\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\varun\anaconda3\lib\site-packages\numpy\lib\function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
index=[[] for i in range(709)]

# %%
for i in range (709):
    index[i] = np.abs(np.array(cor[i]))
    index[i] = np.argpartition(cor[i], -20)[-20:]

# %%
cor[0]
# Out:
# [0.05940507919247928,
#  -0.003634404140177824,
#  0.00696500673930244,
#  0.005396540773478418,
#  0.0983221192861341,
#  -0.01745823768731107,
#  -0.0059929750841418985,
#  0.06918274917518298,
#  0.011458942973586211,
#  -0.00320037264467063,
#  0.018353911763650716,
#  -0.011223297611892728,
#  0.07551000204556481,
#  -0.04561968060585243,
#  -0.009515241898533137,
#  0.03867444395578859,
#  0.08724657550973212,
#  0.041524359424101535,
#  0.043679690428221715,
#  0.014045047494069008,
#  0.002574708498006273,
#  0.06254139905268857,
#  -0.017381627126357536,
#  -0.05619300819895653,
#  -0.025850441556999216,
#  0.042276909916048676,
#  0.014510208356550819,
#  0.03002476020390444,
#  0.07726122742941895,
#  0.06878671167032566,
#  -0.04047335796322168,
#  -0.08415192061510106,
#  -0.026842471316462377,
#  -0.11910692240467226,
#  0.02019351528785557,
#  0.055860561275599914,
#  0.007005350529959399,
#  0.03343611466652094,
#  0.00010736302001576476,
#  0.07262638337348572,
# ...

# %%
index[0]
# Out:
# array([1778, 1465, 1741, 1777, 1398, 1409, 1752,   57,  429, 1779, 1399,
#         399, 1397, 1407, 1405, 1750,  439, 1016,  189, 1388], dtype=int64)

# %%
feature=[[] for i in range(709)]
for i in range(709):
    for j in index[i]:
        feature[i].append('feature_'+str(j+1))

# %%
len(feature[0])
# Out:
# 20

# %%
feature[18]
# Out:
# ['feature_1284',
#  'feature_342',
#  'feature_132',
#  'feature_771',
#  'feature_966',
#  'feature_1422',
#  'feature_747',
#  'feature_699',
#  'feature_102',
#  'feature_27',
#  'feature_131',
#  'feature_702',
#  'feature_331',
#  'feature_101',
#  'feature_692',
#  'feature_121',
#  'feature_1421',
#  'feature_91',
#  'feature_709',
#  'feature_1411']

# %%
arr=[]

# %%
for i in symbols:
    arr.append('model_'+str(i))

# %%
arr[1]
# Out:
# 'model_XRP'

# %%
for i in feature[0]:
    print(i)
# Out:
# feature_1779
# feature_1466
# feature_1742
# feature_1778
# feature_1399
# feature_1410
# feature_1753
# feature_58
# feature_430
# feature_1780
# feature_1400
# feature_400
# feature_1398
# feature_1408
# feature_1406
# feature_1751
# feature_440
# feature_1017
# feature_190
# feature_1389

# %%
del cor

# %%
del index

# %%
def model(i,X_train,y_train):
    arr[i] = Sequential()
    arr[i].add(LSTM(64, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=True))
    arr[i].add(LSTM(32, input_shape=(1, trainX.shape[1]), return_sequences=True))
    arr[i].add(LSTM(16, input_shape=(1, trainX.shape[1]), return_sequences=False))
    arr[i].add(Dense(1))
    arr[i].compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0014))
    history=arr[i].fit(X_train, y_train, epochs=100, batch_size=64, verbose=1, shuffle=False)

# %%
for i in range(420,560):
    features = feature[i]
    target=['target']
    scaler = MinMaxScaler()
    feature_transform = scaler.fit_transform(globals()[symbols[i]][features])
    X_train= pd.DataFrame(columns=features, data=feature_transform, index=globals()[symbols[i]].index)    
    y_train= pd.DataFrame(columns=target, data=globals()[symbols[i]], index=globals()[symbols[i]].index)   
    trainX =np.array(X_train)
    X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
    model(i,X_train,y_train)
    del X_train
    del y_train
    del trainX
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.3534
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3488
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3443
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3398
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3352
# Epoch 6/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3306
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3259
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3211
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3160
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3108
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3053
# Epoch 12/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2995
# ...

# %%
dfv=pd.read_csv(r'C:\Users\varun\Downloads\QmWNurQsLnvvJfTkfNd4rA3Qap11WmX8Upfr9paBx3Mxs9\dataset\validation_dataset.csv')
dfv
# Out:
#            date symbol  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    2022-08-28    BTC   1.000000   1.000000   1.000000   1.000000   1.000000
# 1    2022-08-28    XRP   0.998588   0.001412   0.001412   0.001412   0.001412
# 2    2022-08-28    SRN   0.565678   0.552260   0.546610   0.605226   0.286017
# 3    2022-08-28   SALT   0.404661   0.552260   0.716808   0.605226   0.605226
# 4    2022-08-28    REQ   0.382062   0.877825   0.072740   0.137006   0.235876
# ..          ...    ...        ...        ...        ...        ...        ...
# 704  2022-08-28   MUSD   0.134887   0.133475   0.406073   0.190678   0.121469
# 705  2022-08-28    AVT   0.830508   0.416667   0.752825   0.119350   0.485169
# 706  2022-08-28    GAL   0.223870   0.228107   0.063559   0.077684   0.966102
# 707  2022-08-28   SOFI   0.821328   0.164548   0.872881   0.913842   0.860169
# 708  2022-08-28   USTC   0.872175   0.774718   0.357345   0.096045   0.112288
#
# ...

# %%
j=0

# %%
symbols1=dfv["symbol"].unique()
symbols1
# Out:
# array(['BTC', 'XRP', 'SRN', 'SALT', 'REQ', 'QSP', 'PRE', 'USDT', 'GET',
#        'FUN', 'ETH', 'PAY', 'PLAY', 'PRO', 'TRAC', 'KNC', 'KEY', 'AGIX',
#        'BAT', 'CHAT', 'HT', 'DRGN', 'VGX', 'OMG', 'DCN', 'ENJ', 'PLR',
#        'VEE', 'ANT', 'AST', 'BRD', 'FUEL', 'ZRX', 'VIB', 'WABI', 'OCN',
#        'CRPT', 'VIBE', 'PPT', 'MTL', 'DNT', 'GNO', 'POWR', 'DENT', 'WPR',
#        'TKN', 'STAR', 'MTN', 'RCN', 'POLY', 'GLM', 'REM', 'NCASH', 'ABT',
#        'AXP', 'GVT', 'MANA', 'DGD', 'RDN', 'UTK', 'MKR', 'ELF', 'POE',
#        'TNB', 'TEL', 'CND', 'ENG', 'CHP', 'SNT', 'TEN', 'STORM', 'ELEC',
#        'QASH', 'CAS', 'BFT', 'SAN', 'BNT', 'DMT', 'ZAP', 'FDZ', 'NCT',
#        'RFR', 'BLZ', 'MTH', 'GEM', 'LINK', 'DATA', 'BAX', 'RUFF', 'HOT',
#        'CEL', 'RLC', 'IHT', 'NEXO', 'GEN', 'CNN', 'DGX', 'LBA', 'REN',
#        'SPD', 'FACE', 'QKC', 'ADB', 'MYB', 'CBC', 'OAX', 'XBP', 'COV',
#        'STORJ', 'LET', 'UUU', 'MFT', 'REP', 'AOA', 'HSC', 'BMX', 'CXO',
# ...

# %%
for i in range(709):
    symbols1[i]=(symbols1[i]+str(i))

# %%
symbols1
# Out:
# array(['BTC0', 'XRP1', 'SRN2', 'SALT3', 'REQ4', 'QSP5', 'PRE6', 'USDT7',
#        'GET8', 'FUN9', 'ETH10', 'PAY11', 'PLAY12', 'PRO13', 'TRAC14',
#        'KNC15', 'KEY16', 'AGIX17', 'BAT18', 'CHAT19', 'HT20', 'DRGN21',
#        'VGX22', 'OMG23', 'DCN24', 'ENJ25', 'PLR26', 'VEE27', 'ANT28',
#        'AST29', 'BRD30', 'FUEL31', 'ZRX32', 'VIB33', 'WABI34', 'OCN35',
#        'CRPT36', 'VIBE37', 'PPT38', 'MTL39', 'DNT40', 'GNO41', 'POWR42',
#        'DENT43', 'WPR44', 'TKN45', 'STAR46', 'MTN47', 'RCN48', 'POLY49',
#        'GLM50', 'REM51', 'NCASH52', 'ABT53', 'AXP54', 'GVT55', 'MANA56',
#        'DGD57', 'RDN58', 'UTK59', 'MKR60', 'ELF61', 'POE62', 'TNB63',
#        'TEL64', 'CND65', 'ENG66', 'CHP67', 'SNT68', 'TEN69', 'STORM70',
#        'ELEC71', 'QASH72', 'CAS73', 'BFT74', 'SAN75', 'BNT76', 'DMT77',
#        'ZAP78', 'FDZ79', 'NCT80', 'RFR81', 'BLZ82', 'MTH83', 'GEM84',
#        'LINK85', 'DATA86', 'BAX87', 'RUFF88', 'HOT89', 'CEL90', 'RLC91',
# ...

# %%
j=0

# %%
for (uniquerow), group in dfv.groupby(dfv.symbol):
    globals()[symbols1[j]] = group
    j=j+1

# %%
symbols1[1]
# Out:
# 'XRP1'

# %%
symbols1
# Out:
# array(['BTC0', 'XRP1', 'SRN2', 'SALT3', 'REQ4', 'QSP5', 'PRE6', 'USDT7',
#        'GET8', 'FUN9', 'ETH10', 'PAY11', 'PLAY12', 'PRO13', 'TRAC14',
#        'KNC15', 'KEY16', 'AGIX17', 'BAT18', 'CHAT19', 'HT20', 'DRGN21',
#        'VGX22', 'OMG23', 'DCN24', 'ENJ25', 'PLR26', 'VEE27', 'ANT28',
#        'AST29', 'BRD30', 'FUEL31', 'ZRX32', 'VIB33', 'WABI34', 'OCN35',
#        'CRPT36', 'VIBE37', 'PPT38', 'MTL39', 'DNT40', 'GNO41', 'POWR42',
#        'DENT43', 'WPR44', 'TKN45', 'STAR46', 'MTN47', 'RCN48', 'POLY49',
#        'GLM50', 'REM51', 'NCASH52', 'ABT53', 'AXP54', 'GVT55', 'MANA56',
#        'DGD57', 'RDN58', 'UTK59', 'MKR60', 'ELF61', 'POE62', 'TNB63',
#        'TEL64', 'CND65', 'ENG66', 'CHP67', 'SNT68', 'TEN69', 'STORM70',
#        'ELEC71', 'QASH72', 'CAS73', 'BFT74', 'SAN75', 'BNT76', 'DMT77',
#        'ZAP78', 'FDZ79', 'NCT80', 'RFR81', 'BLZ82', 'MTH83', 'GEM84',
#        'LINK85', 'DATA86', 'BAX87', 'RUFF88', 'HOT89', 'CEL90', 'RLC91',
# ...

# %%
globals()[symbols1[0]]
# Out:
#            date symbol  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 134  2022-08-28  0xBTC    0.34887   0.202684   0.716808   0.311441   0.387006
#
#      feature_6  feature_7  feature_8  ...  feature_2003  feature_2004  \
# 134   0.713277   0.416667   0.734463  ...      0.319209      0.179379
#
#      feature_2005  feature_2006  feature_2007  feature_2008  feature_2009  \
# 134      0.189266      0.172316      0.165254      0.176554      0.158192
#
#      feature_DC1  target  target_DC1
# 134     0.305085     NaN         NaN
#
# [1 rows x 2014 columns]

# %%
for i in range(709):
    features = feature[i]
    target=['target']
    # scaler = MinMaxScaler()
    # feature_transform = scaler.fit_transform(globals()[symbols1[i]][features])
    globals()[symbols1[i]]= pd.DataFrame(columns=feature[i], data=globals()[symbols1[i]][features], index=globals()[symbols1[i]].index)
    # validation_dataset.head()

    # if this doesnt work maybe we can

# %%
globals()[symbols1[0]]
# Out:
#      feature_1779  feature_1466  feature_1742  feature_1778  feature_1399  \
# 134      0.097458      0.612994      0.111582      0.084746      0.580508
#
#      feature_1410  feature_1753  feature_58  feature_430  feature_1780  \
# 134      0.536723      0.218927    0.837571     0.620056      0.096045
#
#      feature_1400  feature_400  feature_1398  feature_1408  feature_1406  \
# 134      0.580508      0.50565      0.591808      0.360169      0.610169
#
#      feature_1751  feature_440  feature_1017  feature_190  feature_1389
# 134       0.19209     0.622881      0.207627     0.596045      0.591808

# %%
globals()[symbols1[708]]
# Out:
#      feature_1272  feature_623  feature_1368  feature_404  feature_374  \
# 641      0.483051     0.107345      0.528249     0.177966     0.111582
#
#      feature_969  feature_1369  feature_1864  feature_13  feature_1109  \
# 641     0.429379      0.588277      0.331921    0.168079      0.381356
#
#      feature_1808  feature_1570  feature_306  feature_408  feature_1281  \
# 641      0.258475      0.689972     0.217514     0.166667      0.504944
#
#      feature_932  feature_1155  feature_333  feature_938  feature_1244
# 641     0.466102      0.504944     0.060734          0.5       0.54096

# %%
for i in range(709):
    validation_X =np.array(globals()[symbols1[i]])
    validation_X = validation_X.reshape(validation_X.shape[0], 1, validation_X.shape[1])
    globals()[symbols1[i]]=  np.asarray(validation_X).astype('float32')

# %%
 globals()[symbols1[0]]
# Out:
# array([[[0.09745762, 0.6129944 , 0.11158192, 0.08474576, 0.5805085 ,
#          0.53672314, 0.21892655, 0.8375706 , 0.6200565 , 0.0960452 ,
#          0.5805085 , 0.50564975, 0.5918079 , 0.3601695 , 0.6101695 ,
#          0.19209039, 0.62288135, 0.20762712, 0.5960452 , 0.5918079 ]]],
#       dtype=float32)

# %%
y_prediction=[]

# %%
arr[i]
# Out:
# 'model_USTC'

# %%
for i in range(560,709):
    y_prediction.append(arr[i].predict(globals()[symbols1[i]]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
#       1 for i in range(560,709):
# ----> 2     y_prediction.append(arr[i].predict(globals()[symbols1[i]]))
#
# AttributeError: 'str' object has no attribute 'predict'

# %%
y_prediction

# %%
# validation_dataset1=pd.read_csv(r'C:\Users\varun\Downloads\QmbVhN84RZYuZ33JMrua8ngtnKcgVsbgM89rU6MTnhDuQa\dataset\train_dataset.csv')
# )
prediction = pd.DataFrame()
prediction['symbol'] = list(symbols[560:709])
prediction['prediction'] = y_prediction

# %%
prediction

# %%
prediction.to_csv(r'C:\Users\varun\OneDrive\Documents\model.csv', index = False, header = None)
